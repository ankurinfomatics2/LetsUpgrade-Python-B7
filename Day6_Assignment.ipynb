# %% [markdown]
# ### **Question 1**
#
# For this challenge, create a bank account class that has two attributes
# * ownerName
# * Balance
#
# And two methods
# * deposit
# * withdraw
#
# As an added requirement, withdrawals may not exceed the available balance.
# Instantiate your class, make several deposits and withdrawals, and test to make sure the account
# can't be overdrawn.

# %% [markdown]
# ****

# %%
# 1. define bankaccount class
class bankAccout():
  def __init__(self, balance = 0, OwnerName = "Ankur Agarwal"):
    self.balance = balance
    self.OwnerName = OwnerName
    # print ("Hello!!! {}. Welcome to our Bank." .format(self.OwnerName))
    # display(self)

  # 2. Function to deposit amount
  def deposit(self):
    amount = float(input("Enter amount to be deposited: "))
    self.balance += amount
    print("\n Amount Deposited:", amount) 

  # 3. function to withdraw the amount
  def withdraw(self):
    amount = float(input("Enter amount to be withdrawn: "))
    if self.balance >= amount:
      self.balance -= amount
      print("\n You Withdrew:", amount)
    else:
      print("\n Insufficient balance  ") 
  
  # 4. function to display the amount
  def display(self):
    if (self.balance != 0):
      print("\nYour Net Available Balance =", self.balance) 
    else:
      print("\nYour Net Available Balance =", self.balance) 
      print("\nPlease deposit the money in your account")

# %% [markdown]
# **5. Driver Code**

# %%
s = bankAccout()

# %%
s.deposit()
# Out:
# Enter amount to be deposited: 200
#
#  Amount Deposited: 200.0

# %%
s.withdraw()
# Out:
# Enter amount to be withdrawn: 100
#
#  You Withdrew: 100.0

# %%
s.display()
# Out:
# Your Net Available Balance = 100.0

# %% [markdown]
# ### **Question 2**
#
# For this challenge,create a cone class that has two attributes:
# * R=Radius
# * h=Height
#
# And two methods:
# * Volume = Π * r2 * (h/3)
# * Surface area : base : Π * r2 , side : Π * r * √(r2 + h2)
#
# Make only one class with functions,as in where required import Math.

# %%
import math

class cone:
  def __init__(self, radius = 0, height = 0):
    self.radius = radius
    self.height = height

  def getValues(self):
    self.radius = float(input("\nEnter the radius of cone:\t"))
    self.height = float(input("\nEnter the height of the cone:\t"))

  
  def coneArea(self):
    s = float(self.radius**2 + self.height**2)
    area = float((22/7)*(self.radius)*(math.sqrt(s)) + (22/7)*(self.radius**2))
    print ("Area of the cone:", area)


  def coneVolume(self):
    volume = float((22/7)*(self.radius**2)*(self.height / 3))
    print ("Volume of the cone: ", volume)

# %%
c = cone()

# %%
c.getValues()
# Out:
# Enter the radius of cone:	4
#
# Enter the height of the cone:	8

# %%
c.coneVolume()
# Out:
# Volume of the cone:  134.09523809523807

# %%
c.coneArea()
# Out:
# Area of the cone: 162.7279897257037
